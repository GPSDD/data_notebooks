# %% [markdown]
# # Google Earth Engine dataset import and querying

# %%
import requests
import json
# Use your authorization key
api_token = input()

# Do not commit your key!

# %%
# Declare the API base url
api_url = "https://api.apihighways.org"
# Convenience function for registering datasets
def register(payload, endpoint = 'v1/dataset', api_url = api_url, api_token = api_token):
    print("Doing authenticated request to the API")
    headers = {'User-Agent': 'python-requests', 'Content-Type': 'application/json', 'Authorization': f'Bearer {api_token}'}
    result = requests.post('/'.join((api_url, endpoint)), json = payload, headers = headers)
    status_code, result = result.status_code, result.text
    print(f"Status code: {status_code}")
    return json.loads(result)

# %% [markdown]
# Google Earth Engine supports several kinds of datasets. What kind of queries are possible is determined by its kind. First, we'll register an [Image](https://developers.google.com/earth-engine/image_overview). The IDs can be obtained from the [Google Earth Engine explorer](https://explorer.earthengine.google.com/#workspace) --linking directly to the dataset is not possible.

# %%
umd_hansen = register(
    payload = {
        # These are the required fields
        "name": "umd_hansen_global_forest_change_2015", # The name will determine the slug
        "connectorType": "rest",
        "provider": "gee", # Google Earth Engine are of provider type 'gee'
        "application": ["data4sdgs"],
        "tableName": "UMD/hansen/global_forest_change_2015_v1_3" # GEE image ID
})
umd_hansen
# Out:
# Doing authenticated request to the API
# Status code: 200
# {'data': {'attributes': {'application': ['data4sdgs'],
#    'attributesPath': None,
#    'blockchain': {},
#    'clonedHost': {},
#    'connectorType': 'rest',
#    'connectorUrl': None,
#    'dataPath': None,
#    'env': 'production',
#    'errorMessage': None,
#    'geoInfo': False,
#    'layerRelevantProps': [],
#    'legend': {'country': [], 'date': [], 'nested': [], 'region': []},
#    'mainDateField': None,
#    'name': 'umd_hansen_global_forest_change_2015',
#    'overwrite': False,
#    'protected': False,
#    'provider': 'gee',
#    'published': True,
#    'slug': 'umd_hansen_global_forest_change_2015',
#    'status': 'pending',
#    'subtitle': None,
#    'tableName': 'UMD/hansen/global_forest_change_2015_v1_3',
#    'taskId': None,
#    'type': None,
#    'updatedAt': '2018-05-14T17:09:54.102Z',
#    'userId': '599c0e5458113b0001d75c47',
#    'verified': False,
#    'widgetRelevantProps': []},
#   'id': '4f507b39-2653-41f9-a880-766baa5a0c47',
#   'type': 'dataset'}}

# %%
umd_hansen["data"]["id"]
# Out:
# '4f507b39-2653-41f9-a880-766baa5a0c47'

# %% [markdown]
# Some examples of possible queries to `Image `s

# %%
def query(dataset_id, query):
    return json.loads(
        requests.get(
            f"{api_url}/query/{dataset_id}?sql={query}"
        ).text
    )

query(
    umd_hansen["data"]["id"],
    "SELECT ST_HISTOGRAM(raster, lossyear, 15, true) FROM 'UMD/hansen/global_forest_change_2015_v1_3'"
)
# Out:
# {'data': [{'st_histogram': {'lossyear': [[0.0, 7081461.411764656],
#      [1.0666666666666667, 0.0],
#      [2.1333333333333333, 0.0],
#      [3.2, 0.0],
#      [4.266666666666667, 1.0],
#      [5.333333333333333, 0.0],
#      [6.4, 0.0],
#      [7.466666666666667, 1.0],
#      [8.533333333333333, 1.0],
#      [9.6, 1.0],
#      [10.666666666666666, 2.0],
#      [11.733333333333333, 0.0],
#      [12.8, 0.0],
#      [13.866666666666667, 4.0],
#      [14.933333333333334, 2.0]]}}],
#  'meta': {}}

# %% [markdown]
# Queries can be also made to the generic 'query' endpoint. The slug must be provided.

# %%
def query_no_id(query):
    return json.loads(
        requests.get(
            f"{api_url}/query?sql={query}"
        ).text
    )

dataset_slug = umd_hansen["data"]["attributes"]["slug"]
query_no_id(
    f"SELECT ST_HISTOGRAM(raster, lossyear, 15, true) FROM {dataset_slug}"
)
# Out:
# {'data': [{'st_histogram': {'lossyear': [[0, 7081461.411764656],
#      [1.0666666666666667, 0],
#      [2.1333333333333333, 0],
#      [3.2, 0],
#      [4.266666666666667, 1],
#      [5.333333333333333, 0],
#      [6.4, 0],
#      [7.466666666666667, 1],
#      [8.533333333333333, 1],
#      [9.6, 1],
#      [10.666666666666666, 2],
#      [11.733333333333333, 0],
#      [12.8, 0],
#      [13.866666666666667, 4],
#      [14.933333333333334, 2]]}}],
#  'meta': {}}

# %% [markdown]
# [ImageCollections](https://developers.google.com/earth-engine/ic_creating) are sets of images. They can be registered as datasets, but queries are done to the information of the ImageCollection, not the Images themselves. We'll use the Copernicus S2 1C imagery as an example.

# %%
# Registering the dataset
copernicus = register(
    payload = {
        # These are the required fields
        "name": "COPERNICUS S2 Level 1C imagery", # The name will determine the slug
        "connectorType": "rest",
        "provider": "gee", # Google Earth Engine are of provider type 'gee'
        "application": ["data4sdgs"],
        "tableName": "COPERNICUS/S2" # GEE image ID
})
copernicus
# Out:
# Doing authenticated request to the API
# Status code: 200
# {'data': {'attributes': {'application': ['data4sdgs'],
#    'attributesPath': None,
#    'blockchain': {},
#    'clonedHost': {},
#    'connectorType': 'rest',
#    'connectorUrl': None,
#    'dataPath': None,
#    'env': 'production',
#    'errorMessage': None,
#    'geoInfo': False,
#    'layerRelevantProps': [],
#    'legend': {'country': [], 'date': [], 'nested': [], 'region': []},
#    'mainDateField': None,
#    'name': 'COPERNICUS S2 Level 1C imagery',
#    'overwrite': False,
#    'protected': False,
#    'provider': 'gee',
#    'published': True,
#    'slug': 'COPERNICUS-S2-Level-1C-imagery',
#    'status': 'pending',
#    'subtitle': None,
#    'tableName': 'COPERNICUS/S2',
#    'taskId': None,
#    'type': None,
#    'updatedAt': '2018-05-14T17:35:33.537Z',
#    'userId': '599c0e5458113b0001d75c47',
#    'verified': False,
#    'widgetRelevantProps': []},
#   'id': 'c38673bf-29a6-4b75-9099-4314ce269a31',
#   'type': 'dataset'}}

# %%
# The output will be metadata relating to the Images in the ImageCollection
query(
    copernicus["data"]["id"],
    "SELECT * from 'COPERNICUS/S2' limit 10"
)
# Out:
# {'data': [{'CLOUDY_PIXEL_PERCENTAGE': 0.0,
#    'CLOUD_COVERAGE_ASSESSMENT': 0.010707692307692307,
#    'DATASTRIP_ID': 'S2A_OPER_MSI_L1C_DS_EPA__20160606T223605_S20150627T102531_N02.02',
#    'DATATAKE_IDENTIFIER': 'GS2A_20150627T102537_000062_N02.02',
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0,
#    'ECMWF_DATA_REF': 'S2__OPER_AUX_ECMWFD_FAKE_19800101T000000_V19800101T000000_19800101T000000',
#    'FORMAT_CORRECTNESS_FLAG': 'PASSED',
#    'GENERAL_QUALITY_FLAG': 'PASSED',
#    'GENERATION_TIME': 1465314766000,
#    'GEOMETRIC_QUALITY_FLAG': 'PASSED',
#    'GRANULE_ID': 'S2A_OPER_MSI_L1C_TL_EPA__20160606T223605_A000062_T31RCL_N02.02',
#    'GRI_FILENAME': 'S2A_OPER_AUX_GRI065_PDMC_20130621T120000_S20130101T000000',
#    'IERS_BULLETIN_FILENAME': 'S2__OPER_AUX_UT1UTC_PDMC_20150625T000000_V20150626T000000_20160625T000000',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 103.965471634376,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 102.245777794173,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 103.091486838831,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 103.753229567026,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 101.277174913552,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 101.897620500158,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 102.416933650149,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 102.725991378684,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 103.023729563746,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 103.330261145428,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 101.587249585053,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 103.625932116468,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 104.268281291389,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 10.4493442111546,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 10.342072708265,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 10.3781208976365,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 10.3980344773923,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 10.3540810070976,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 10.3676352976004,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 10.3633646486197,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 10.3766701595358,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 10.3918880450569,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 10.409047299956,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 10.3598860673037,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 10.4280169663968,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 10.4726949936646,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 98.2934185023958,
#    'MEAN_SOLAR_ZENITH_ANGLE': 18.8695856990462,
#    'MGRS_TILE': '31RCL',
#    'PROCESSING_BASELINE': '02.02',
#    'PRODUCTION_DEM_TYPE': 'S2__OPER_DEM_GLOBEF_PDMC_19800101T000000_S19800101T000000',
#    'PRODUCT_ID': 'S2A_OPER_PRD_MSIL1C_PDMC_20160607T155246_R062_V20150627T102531_20150627T102531',
#    'PRODUCT_URI': '754_2016-06-07T01_11',
#    'RADIOMETRIC_QUALITY_FLAG': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.967962284766511,
#    'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#    'SENSING_ORBIT_NUMBER': 62.0,
#    'SENSOR_QUALITY_FLAG': 'PASSED',
#    'SOLAR_IRRADIANCE_B1': 1913.57,
#    'SOLAR_IRRADIANCE_B10': 367.15,
#    'SOLAR_IRRADIANCE_B11': 245.59,
#    'SOLAR_IRRADIANCE_B12': 85.25,
#    'SOLAR_IRRADIANCE_B2': 1941.63,
#    'SOLAR_IRRADIANCE_B3': 1822.61,
#    'SOLAR_IRRADIANCE_B4': 1512.79,
#    'SOLAR_IRRADIANCE_B5': 1425.56,
#    'SOLAR_IRRADIANCE_B6': 1288.32,
#    'SOLAR_IRRADIANCE_B7': 1163.19,
#    'SOLAR_IRRADIANCE_B8': 1036.39,
#    'SOLAR_IRRADIANCE_B8A': 955.19,
#    'SOLAR_IRRADIANCE_B9': 813.04,
#    'SPACECRAFT_NAME': 'Sentinel-2A',
#    'system:asset_size': 129008712,
#    'system:footprint': {'coordinates': [[2.0823420055272694,
#       28.022371475142155],
#      [2.082262387713162, 28.022460994622374],
#      [1.7870267921380452, 28.020172100522007],
#      [1.7863863638768989, 28.019300827799174],
#      [1.7840385788154567, 28.010599213518702],
#      [1.7583696085580722, 27.9074708061136],
#      [1.7138484027983951, 27.72807167221268],
#      [1.711234871844144, 27.71720577206124],
#      [1.7112611391967587, 27.714974277442444],
#      [1.7119348947961275, 27.714682202980047],
#      [1.7139838289586986, 27.71406533734163],
#      [1.7676420145675962, 27.705345166014425],
#      [1.9106692751128727, 27.682352691622302],
#      [1.9653060360042989, 27.67356410080027],
#      [1.970992862852016, 27.67270366436133],
#      [1.9756637522563858, 27.672015966240707],
#      [2.0845963559712533, 27.656438224472712],
#      [2.0853071966042025, 27.65644288605324],
#      [2.085405603161776, 27.657703616668854],
#      [2.0823420055272694, 28.022371475142155]],
#     'type': 'LinearRing'},
#    'system:index': '20150627T102531_20160606T223605_T31RCL',
#    'system:time_end': 1435400731456,
#    'system:time_start': 1435400731456},
#   {'CLOUDY_PIXEL_PERCENTAGE': 0.0,
#    'CLOUD_COVERAGE_ASSESSMENT': 0.010707692307692307,
#    'DATASTRIP_ID': 'S2A_OPER_MSI_L1C_DS_EPA__20160606T223605_S20150627T102531_N02.02',
#    'DATATAKE_IDENTIFIER': 'GS2A_20150627T102537_000062_N02.02',
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0,
#    'ECMWF_DATA_REF': 'S2__OPER_AUX_ECMWFD_FAKE_19800101T000000_V19800101T000000_19800101T000000',
#    'FORMAT_CORRECTNESS_FLAG': 'PASSED',
#    'GENERAL_QUALITY_FLAG': 'PASSED',
#    'GENERATION_TIME': 1465314766000,
#    'GEOMETRIC_QUALITY_FLAG': 'PASSED',
#    'GRANULE_ID': 'S2A_OPER_MSI_L1C_TL_EPA__20160606T223605_A000062_T31RCM_N02.02',
#    'GRI_FILENAME': 'S2A_OPER_AUX_GRI065_PDMC_20130621T120000_S20130101T000000',
#    'IERS_BULLETIN_FILENAME': 'S2__OPER_AUX_UT1UTC_PDMC_20150625T000000_V20150626T000000_20160625T000000',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 108.192608975352,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 104.791945416046,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 106.330341968715,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 107.857080062688,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 102.544262170019,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 103.819727757883,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 104.988764977702,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 105.630369609097,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 106.260172462526,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 106.897562903146,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 103.18111044659,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 107.522353897336,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 108.829691917951,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 10.9229808236822,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 10.8595781276634,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 10.883681441104,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 10.8996836776471,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 10.8426434994432,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 10.8409268460308,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 10.8544054847848,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 10.8643968685424,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 10.876100298319,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 10.8897303587767,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 10.8361824607237,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 10.9049829337849,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 10.9423655470273,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 100.816831513226,
#    'MEAN_SOLAR_ZENITH_ANGLE': 19.0834100082928,
#    'MGRS_TILE': '31RCM',
#    'PROCESSING_BASELINE': '02.02',
#    'PRODUCTION_DEM_TYPE': 'S2__OPER_DEM_GLOBEF_PDMC_19800101T000000_S19800101T000000',
#    'PRODUCT_ID': 'S2A_OPER_PRD_MSIL1C_PDMC_20160607T155246_R062_V20150627T102531_20150627T102531',
#    'PRODUCT_URI': '754_2016-06-07T01_11',
#    'RADIOMETRIC_QUALITY_FLAG': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.967962284766511,
#    'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#    'SENSING_ORBIT_NUMBER': 62.0,
#    'SENSOR_QUALITY_FLAG': 'PASSED',
#    'SOLAR_IRRADIANCE_B1': 1913.57,
#    'SOLAR_IRRADIANCE_B10': 367.15,
#    'SOLAR_IRRADIANCE_B11': 245.59,
#    'SOLAR_IRRADIANCE_B12': 85.25,
#    'SOLAR_IRRADIANCE_B2': 1941.63,
#    'SOLAR_IRRADIANCE_B3': 1822.61,
#    'SOLAR_IRRADIANCE_B4': 1512.79,
#    'SOLAR_IRRADIANCE_B5': 1425.56,
#    'SOLAR_IRRADIANCE_B6': 1288.32,
#    'SOLAR_IRRADIANCE_B7': 1163.19,
#    'SOLAR_IRRADIANCE_B8': 1036.39,
#    'SOLAR_IRRADIANCE_B8A': 955.19,
#    'SOLAR_IRRADIANCE_B9': 813.04,
#    'SPACECRAFT_NAME': 'Sentinel-2A',
#    'system:asset_size': 220675387,
#    'system:footprint': {'coordinates': [[2.012708483059923, 28.92447255339638],
#      [2.0126600696610195, 28.92443188383271],
#      [2.0043511538719923, 28.89158868228552],
#      [1.8887691405934433, 28.431196778323272],
#      [1.7741160516747791, 27.97070487780498],
#      [1.76828417416827, 27.947094201252604],
#      [1.7656630663300565, 27.936238663769473],
#      [1.7647893739281018, 27.932430164209826],
#      [1.7647956145260995, 27.93187910414429],
#      [1.7648669357094595, 27.93179178549703],
#      [1.7661147038085616, 27.93171072658749],
#      [2.0829862864756725, 27.93418546646187],
#      [2.0830875314688213, 27.934255775973494],
#      [2.078851376456305, 28.42970729919896],
#      [2.0745068406970018, 28.925101898610862],
#      [2.0744265634985863, 28.92519132440636],
#      [2.013343091961301, 28.92475754653414],
#      [2.012708483059923, 28.92447255339638]],
#     'type': 'LinearRing'},
#    'system:index': '20150627T102531_20160606T223605_T31RCM',
#    'system:time_end': 1435400731456,
#    'system:time_start': 1435400731456},
#   {'CLOUDY_PIXEL_PERCENTAGE': 0.0,
#    'CLOUD_COVERAGE_ASSESSMENT': 0.010707692307692307,
#    'DATASTRIP_ID': 'S2A_OPER_MSI_L1C_DS_EPA__20160606T223605_S20150627T102531_N02.02',
#    'DATATAKE_IDENTIFIER': 'GS2A_20150627T102537_000062_N02.02',
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0,
#    'ECMWF_DATA_REF': 'S2__OPER_AUX_ECMWFD_FAKE_19800101T000000_V19800101T000000_19800101T000000',
#    'FORMAT_CORRECTNESS_FLAG': 'PASSED',
#    'GENERAL_QUALITY_FLAG': 'PASSED',
#    'GENERATION_TIME': 1465314766000,
#    'GEOMETRIC_QUALITY_FLAG': 'PASSED',
#    'GRANULE_ID': 'S2A_OPER_MSI_L1C_TL_EPA__20160606T223605_A000062_T31RDL_N02.02',
#    'GRI_FILENAME': 'S2A_OPER_AUX_GRI065_PDMC_20130621T120000_S20130101T000000',
#    'IERS_BULLETIN_FILENAME': 'S2__OPER_AUX_UT1UTC_PDMC_20150625T000000_V20150626T000000_20160625T000000',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 97.7561234760071,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 97.7570682548798,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 97.7788875192984,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 97.9412047779949,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 97.6416745748411,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 97.4757056762557,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 97.4432280440041,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 97.478957419582,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 97.5089365191053,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 97.5668016237041,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 97.537092814233,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 97.6194782884786,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 97.8196210487669,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 5.63739210399922,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 5.39389829386532,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 5.48276566907498,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 5.60173518230675,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 5.28065902196537,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 5.33336350228758,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 5.39749360885817,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 5.43807229244015,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 5.48263987304777,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 5.53076901716288,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 5.30468245493307,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 5.58238209488754,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 5.69695027122063,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 99.1811306953453,
#    'MEAN_SOLAR_ZENITH_ANGLE': 17.9936420056361,
#    'MGRS_TILE': '31RDL',
#    'PROCESSING_BASELINE': '02.02',
#    'PRODUCTION_DEM_TYPE': 'S2__OPER_DEM_GLOBEF_PDMC_19800101T000000_S19800101T000000',
#    'PRODUCT_ID': 'S2A_OPER_PRD_MSIL1C_PDMC_20160607T155246_R062_V20150627T102531_20150627T102531',
#    'PRODUCT_URI': '754_2016-06-07T01_11',
#    'RADIOMETRIC_QUALITY_FLAG': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.967962284766511,
#    'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#    'SENSING_ORBIT_NUMBER': 62.0,
#    'SENSOR_QUALITY_FLAG': 'PASSED',
#    'SOLAR_IRRADIANCE_B1': 1913.57,
#    'SOLAR_IRRADIANCE_B10': 367.15,
#    'SOLAR_IRRADIANCE_B11': 245.59,
#    'SOLAR_IRRADIANCE_B12': 85.25,
#    'SOLAR_IRRADIANCE_B2': 1941.63,
#    'SOLAR_IRRADIANCE_B3': 1822.61,
#    'SOLAR_IRRADIANCE_B4': 1512.79,
#    'SOLAR_IRRADIANCE_B5': 1425.56,
#    'SOLAR_IRRADIANCE_B6': 1288.32,
#    'SOLAR_IRRADIANCE_B7': 1163.19,
#    'SOLAR_IRRADIANCE_B8': 1036.39,
#    'SOLAR_IRRADIANCE_B8A': 955.19,
#    'SOLAR_IRRADIANCE_B9': 813.04,
#    'SPACECRAFT_NAME': 'Sentinel-2A',
#    'system:asset_size': 525709943,
#    'system:footprint': {'coordinates': [[1.982259700143993, 28.02168904317098],
#      [1.9822567137088078, 28.021674261341968],
#      [1.9855076420416131, 27.672899298785342],
#      [1.985540868578425, 27.672866434613674],
#      [1.9855547565315195, 27.672824003791046],
#      [1.98557775379674, 27.672814459814262],
#      [1.9864964594888357, 27.672549302019195],
#      [1.9889403360786353, 27.67202426516326],
#      [3.0951237194558154, 27.469031944974404],
#      [3.0972594189328193, 27.46875827349871],
#      [3.098481303288883, 27.468757438085685],
#      [3.098525816684983, 27.46879225925593],
#      [3.098577366614194, 27.468818420273383],
#      [3.098582108598572, 27.468836218874205],
#      [3.0986850556645553, 27.47001745567322],
#      [3.0991868683891455, 28.0253997732516],
#      [3.0991454902489814, 28.025441221997742],
#      [3.0991081658202297, 28.02548980894313],
#      [1.982357804651594, 28.021757471735746],
#      [1.982311216182582, 28.021720542938272],
#      [1.982259700143993, 28.02168904317098]],
#     'type': 'LinearRing'},
#    'system:index': '20150627T102531_20160606T223605_T31RDL',
#    'system:time_end': 1435400731456,
#    'system:time_start': 1435400731456},
#   {'CLOUDY_PIXEL_PERCENTAGE': 0.0,
#    'CLOUD_COVERAGE_ASSESSMENT': 0.010707692307692307,
#    'DATASTRIP_ID': 'S2A_OPER_MSI_L1C_DS_EPA__20160606T223605_S20150627T102531_N02.02',
#    'DATATAKE_IDENTIFIER': 'GS2A_20150627T102537_000062_N02.02',
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0,
#    'ECMWF_DATA_REF': 'S2__OPER_AUX_ECMWFD_FAKE_19800101T000000_V19800101T000000_19800101T000000',
#    'FORMAT_CORRECTNESS_FLAG': 'PASSED',
#    'GENERAL_QUALITY_FLAG': 'PASSED',
#    'GENERATION_TIME': 1465314766000,
#    'GEOMETRIC_QUALITY_FLAG': 'PASSED',
#    'GRANULE_ID': 'S2A_OPER_MSI_L1C_TL_EPA__20160606T223605_A000062_T31RDM_N02.02',
#    'GRI_FILENAME': 'S2A_OPER_AUX_GRI065_PDMC_20130621T120000_S20130101T000000',
#    'IERS_BULLETIN_FILENAME': 'S2__OPER_AUX_UT1UTC_PDMC_20150625T000000_V20150626T000000_20160625T000000',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 102.234962344309,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 101.307711528755,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 101.725498796045,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 102.16737718115,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 100.449720458472,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 100.883323009995,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 101.247992839664,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 101.455146144359,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 101.63812891849,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 101.829134996897,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 100.657698000189,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 102.001259356649,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 102.399243111422,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 7.04780319849454,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 6.85130368633546,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 6.92185723458046,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 7.00665460156132,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 6.80026382863491,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 6.83637576663103,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 6.87842327420011,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 6.90596016050866,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 6.93676970592055,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 6.97065351679586,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 6.81314275649428,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 7.00754749780097,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 7.09159645430711,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 101.834872986995,
#    'MEAN_SOLAR_ZENITH_ANGLE': 18.2147129418463,
#    'MGRS_TILE': '31RDM',
#    'PROCESSING_BASELINE': '02.02',
#    'PRODUCTION_DEM_TYPE': 'S2__OPER_DEM_GLOBEF_PDMC_19800101T000000_S19800101T000000',
#    'PRODUCT_ID': 'S2A_OPER_PRD_MSIL1C_PDMC_20160607T155246_R062_V20150627T102531_20150627T102531',
#    'PRODUCT_URI': '754_2016-06-07T01_11',
#    'RADIOMETRIC_QUALITY_FLAG': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.967962284766511,
#    'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#    'SENSING_ORBIT_NUMBER': 62.0,
#    'SENSOR_QUALITY_FLAG': 'PASSED',
#    'SOLAR_IRRADIANCE_B1': 1913.57,
#    'SOLAR_IRRADIANCE_B10': 367.15,
#    'SOLAR_IRRADIANCE_B11': 245.59,
#    'SOLAR_IRRADIANCE_B12': 85.25,
#    'SOLAR_IRRADIANCE_B2': 1941.63,
#    'SOLAR_IRRADIANCE_B3': 1822.61,
#    'SOLAR_IRRADIANCE_B4': 1512.79,
#    'SOLAR_IRRADIANCE_B5': 1425.56,
#    'SOLAR_IRRADIANCE_B6': 1288.32,
#    'SOLAR_IRRADIANCE_B7': 1163.19,
#    'SOLAR_IRRADIANCE_B8': 1036.39,
#    'SOLAR_IRRADIANCE_B8A': 955.19,
#    'SOLAR_IRRADIANCE_B9': 813.04,
#    'SPACECRAFT_NAME': 'Sentinel-2A',
#    'system:asset_size': 1316047009,
#    'system:footprint': {'coordinates': [[1.9831251775305245,
#       27.93353275128602],
#      [1.983162956689856, 27.933484497274883],
#      [3.0990043765254573, 27.937203261446623],
#      [3.099051337903137, 27.937239801900898],
#      [3.099106330193331, 27.93727276918284],
#      [3.1000339425402546, 28.928245610472892],
#      [3.0999921812453652, 28.928287044996537],
#      [3.099954473733555, 28.92833566530989],
#      [2.0130597059161417, 28.924755457318266],
#      [2.013030418560695, 28.92473244484978],
#      [2.0129910450290454, 28.924731787226037],
#      [2.0129744588458847, 28.924714625461174],
#      [2.0105393455478047, 28.921442195850833],
#      [2.0105295587443215, 28.921419514257305],
#      [2.0081499352699512, 28.912736900134416],
#      [1.9860194081338998, 28.825566228184087],
#      [1.9808972346249822, 28.804225439398774],
#      [1.975331561973503, 28.776019765166406],
#      [1.975044387345576, 28.7738434544315],
#      [1.979107032428227, 28.35371913395942],
#      [1.983083366640703, 27.93357391509752],
#      [1.9831251775305245, 27.93353275128602]],
#     'type': 'LinearRing'},
#    'system:index': '20150627T102531_20160606T223605_T31RDM',
#    'system:time_end': 1435400731456,
#    'system:time_start': 1435400731456},
#   {'CLOUDY_PIXEL_PERCENTAGE': 0.1239,
#    'CLOUD_COVERAGE_ASSESSMENT': 0.010707692307692307,
#    'DATASTRIP_ID': 'S2A_OPER_MSI_L1C_DS_EPA__20160606T223605_S20150627T102531_N02.02',
#    'DATATAKE_IDENTIFIER': 'GS2A_20150627T102537_000062_N02.02',
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0,
#    'ECMWF_DATA_REF': 'S2__OPER_AUX_ECMWFD_FAKE_19800101T000000_V19800101T000000_19800101T000000',
#    'FORMAT_CORRECTNESS_FLAG': 'PASSED',
#    'GENERAL_QUALITY_FLAG': 'PASSED',
#    'GENERATION_TIME': 1465314766000,
#    'GEOMETRIC_QUALITY_FLAG': 'PASSED',
#    'GRANULE_ID': 'S2A_OPER_MSI_L1C_TL_EPA__20160606T223605_A000062_T31RDN_N02.02',
#    'GRI_FILENAME': 'S2A_OPER_AUX_GRI065_PDMC_20130621T120000_S20130101T000000',
#    'IERS_BULLETIN_FILENAME': 'S2__OPER_AUX_UT1UTC_PDMC_20150625T000000_V20150626T000000_20160625T000000',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 100.144589369039,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 100.15925635039,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 100.154815119265,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 100.155001007972,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 100.102023769003,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 100.091003490789,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 100.086935499802,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 100.101018124717,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 100.101416965179,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 100.100325207648,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 100.103854423935,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 100.084587798412,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 100.159040467086,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 8.13989859639587,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 7.9832917655626,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 8.04057140007152,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 8.10880692846187,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 7.95662896212458,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 7.98711109169737,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 8.00810751379187,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 8.02997364648625,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 8.05457167712864,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 8.07378403353648,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 7.96817984171832,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 8.10758096154475,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 8.17977875185404,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 104.415035586313,
#    'MEAN_SOLAR_ZENITH_ANGLE': 18.4751073744239,
#    'MGRS_TILE': '31RDN',
#    'PROCESSING_BASELINE': '02.02',
#    'PRODUCTION_DEM_TYPE': 'S2__OPER_DEM_GLOBEF_PDMC_19800101T000000_S19800101T000000',
#    'PRODUCT_ID': 'S2A_OPER_PRD_MSIL1C_PDMC_20160607T155246_R062_V20150627T102531_20150627T102531',
#    'PRODUCT_URI': '754_2016-06-07T01_11',
#    'RADIOMETRIC_QUALITY_FLAG': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.967962284766511,
#    'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#    'SENSING_ORBIT_NUMBER': 62.0,
#    'SENSOR_QUALITY_FLAG': 'PASSED',
#    'SOLAR_IRRADIANCE_B1': 1913.57,
#    'SOLAR_IRRADIANCE_B10': 367.15,
#    'SOLAR_IRRADIANCE_B11': 245.59,
#    'SOLAR_IRRADIANCE_B12': 85.25,
#    'SOLAR_IRRADIANCE_B2': 1941.63,
#    'SOLAR_IRRADIANCE_B3': 1822.61,
#    'SOLAR_IRRADIANCE_B4': 1512.79,
#    'SOLAR_IRRADIANCE_B5': 1425.56,
#    'SOLAR_IRRADIANCE_B6': 1288.32,
#    'SOLAR_IRRADIANCE_B7': 1163.19,
#    'SOLAR_IRRADIANCE_B8': 1036.39,
#    'SOLAR_IRRADIANCE_B8A': 955.19,
#    'SOLAR_IRRADIANCE_B9': 813.04,
#    'SPACECRAFT_NAME': 'Sentinel-2A',
#    'system:asset_size': 1116177222,
#    'system:footprint': {'coordinates': [[3.1008780485388874,
#       29.830470263601825],
#      [3.100840034386958, 29.830518791342545],
#      [2.24152280009599, 29.8283798929139],
#      [2.2414824745678374, 29.828348622404995],
#      [2.2414318611997444, 29.82833208921058],
#      [2.2414226997356037, 29.828311060551517],
#      [2.240515573782273, 29.825056240725328],
#      [2.230265939043919, 29.78492748408343],
#      [2.1157949918512062, 29.334242091045088],
#      [2.0022752693187997, 28.88345031737413],
#      [1.9913163172186696, 28.83950263010787],
#      [1.9910227663699107, 28.83786598006995],
#      [1.9910411365772382, 28.835963363426377],
#      [1.991081610800697, 28.835923754860143],
#      [1.9911129746154683, 28.8358782369052],
#      [1.9911331370795204, 28.835874474805006],
#      [1.992782233609361, 28.8357961199266],
#      [3.09984624645437, 28.839519260256107],
#      [3.099893591078829, 28.839555745925008],
#      [3.0999490432423897, 28.839588759860728],
#      [3.1009201165487164, 29.830428786931765],
#      [3.1008780485388874, 29.830470263601825]],
#     'type': 'LinearRing'},
#    'system:index': '20150627T102531_20160606T223605_T31RDN',
#    'system:time_end': 1435400731456,
#    'system:time_start': 1435400731456},
#   {'CLOUDY_PIXEL_PERCENTAGE': 0.0545,
#    'CLOUD_COVERAGE_ASSESSMENT': 0.07903571428571428,
#    'DATASTRIP_ID': 'S2A_OPER_MSI_L1C_DS_EPA__20160606T223605_S20150627T102531_N02.02',
#    'DATATAKE_IDENTIFIER': 'GS2A_20150627T102537_000062_N02.02',
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0,
#    'ECMWF_DATA_REF': 'S2__OPER_AUX_ECMWFD_FAKE_19800101T000000_V19800101T000000_19800101T000000',
#    'FORMAT_CORRECTNESS_FLAG': 'PASSED',
#    'GENERAL_QUALITY_FLAG': 'PASSED',
#    'GENERATION_TIME': 1465314504000,
#    'GEOMETRIC_QUALITY_FLAG': 'PASSED',
#    'GRANULE_ID': 'S2A_OPER_MSI_L1C_TL_EPA__20160606T223605_A000062_T31RDP_N02.02',
#    'GRI_FILENAME': 'S2A_OPER_AUX_GRI065_PDMC_20130621T120000_S20130101T000000',
#    'IERS_BULLETIN_FILENAME': 'S2__OPER_AUX_UT1UTC_PDMC_20150625T000000_V20150626T000000_20160625T000000',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 103.073532970369,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 101.913293647545,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 102.408184816212,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 102.89048738638,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 101.114172062948,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 101.55426001063,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 101.976798117946,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 102.209952586005,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 102.462484236292,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 102.694434771098,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 101.328283596205,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 102.831311162153,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 103.250607064481,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 8.99165922575033,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 8.86434608241753,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 8.91021463204026,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 8.96110604836174,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 8.83321984541526,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 8.85581506124923,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 8.88444228095515,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 8.90206533438603,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 8.9247865841439,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 8.94696434281732,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 8.84474705238659,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 8.9666813295849,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 9.02429551923368,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 106.916730007826,
#    'MEAN_SOLAR_ZENITH_ANGLE': 18.7735126532164,
#    'MGRS_TILE': '31RDP',
#    'PROCESSING_BASELINE': '02.02',
#    'PRODUCTION_DEM_TYPE': 'S2__OPER_DEM_GLOBEF_PDMC_19800101T000000_S19800101T000000',
#    'PRODUCT_ID': 'S2A_OPER_PRD_MSIL1C_PDMC_20160607T154824_R062_V20150627T102531_20150627T102531',
#    'PRODUCT_URI': '404_2016-06-07T01_10',
#    'RADIOMETRIC_QUALITY_FLAG': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.967962284766511,
#    'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#    'SENSING_ORBIT_NUMBER': 62.0,
#    'SENSOR_QUALITY_FLAG': 'PASSED',
#    'SOLAR_IRRADIANCE_B1': 1913.57,
#    'SOLAR_IRRADIANCE_B10': 367.15,
#    'SOLAR_IRRADIANCE_B11': 245.59,
#    'SOLAR_IRRADIANCE_B12': 85.25,
#    'SOLAR_IRRADIANCE_B2': 1941.63,
#    'SOLAR_IRRADIANCE_B3': 1822.61,
#    'SOLAR_IRRADIANCE_B4': 1512.79,
#    'SOLAR_IRRADIANCE_B5': 1425.56,
#    'SOLAR_IRRADIANCE_B6': 1288.32,
#    'SOLAR_IRRADIANCE_B7': 1163.19,
#    'SOLAR_IRRADIANCE_B8': 1036.39,
#    'SOLAR_IRRADIANCE_B8A': 955.19,
#    'SOLAR_IRRADIANCE_B9': 813.04,
#    'SPACECRAFT_NAME': 'Sentinel-2A',
#    'system:asset_size': 812669500,
#    'system:footprint': {'coordinates': [[3.1018056184108143,
#       30.733071600302306],
#      [3.1017672210858556, 30.73312008973323],
#      [2.472697685306693, 30.73208888336932],
#      [2.472656928628149, 30.732057664781564],
#      [2.472605831880264, 30.732041191951367],
#      [2.4725964729547423, 30.73202015853799],
#      [2.4716739488474557, 30.72876735678589],
#      [2.46829670071148, 30.716029708552803],
#      [2.467376073944745, 30.71250658436284],
#      [2.315189053892543, 30.119746607250395],
#      [2.220026283270636, 29.744527130615857],
#      [2.219122588768384, 29.74072169823709],
#      [2.219126867013723, 29.74017077018125],
#      [2.219167097551105, 29.740131679076317],
#      [2.219197195420597, 29.740086133003913],
#      [2.219218361515392, 29.740081893587007],
#      [2.2204684546668623, 29.739998402152793],
#      [3.100728057260105, 29.742255941817398],
#      [3.100775861671179, 29.742292432108663],
#      [3.1008317737703734, 29.742325466954163],
#      [3.1018481461609166, 30.733030109414546],
#      [3.1018056184108143, 30.733071600302306]],
#     'type': 'LinearRing'},
#    'system:index': '20150627T102531_20160606T223605_T31RDP',
#    'system:time_end': 1435400731456,
#    'system:time_start': 1435400731456},
#   {'CLOUDY_PIXEL_PERCENTAGE': 0.0,
#    'CLOUD_COVERAGE_ASSESSMENT': 0.07903571428571428,
#    'DATASTRIP_ID': 'S2A_OPER_MSI_L1C_DS_EPA__20160606T223605_S20150627T102531_N02.02',
#    'DATATAKE_IDENTIFIER': 'GS2A_20150627T102537_000062_N02.02',
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0,
#    'ECMWF_DATA_REF': 'S2__OPER_AUX_ECMWFD_FAKE_19800101T000000_V19800101T000000_19800101T000000',
#    'FORMAT_CORRECTNESS_FLAG': 'PASSED',
#    'GENERAL_QUALITY_FLAG': 'PASSED',
#    'GENERATION_TIME': 1465314504000,
#    'GEOMETRIC_QUALITY_FLAG': 'PASSED',
#    'GRANULE_ID': 'S2A_OPER_MSI_L1C_TL_EPA__20160606T223605_A000062_T31RDQ_N02.02',
#    'GRI_FILENAME': 'S2A_OPER_AUX_GRI065_PDMC_20130621T120000_S20130101T000000',
#    'IERS_BULLETIN_FILENAME': 'S2__OPER_AUX_UT1UTC_PDMC_20150625T000000_V20150626T000000_20160625T000000',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 101.204422027445,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 100.79194822871,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 100.927622860213,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 101.003746905801,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 100.55095522606,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 100.668922157293,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 100.784622073529,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 100.855919501789,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 100.915806660592,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 100.985516198816,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 100.606398115,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 101.045747293413,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 101.224588563883,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 9.85647602948046,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 9.72931658271252,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 9.76949933386845,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 9.82036039551296,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 9.71168980159199,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 9.72267078050555,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 9.74722274587575,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 9.76347988186851,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 9.78185683677964,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 9.80225030308615,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 9.71176108667402,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 9.82466398204417,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 9.88442735167096,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 109.332290603226,
#    'MEAN_SOLAR_ZENITH_ANGLE': 19.1079017314485,
#    'MGRS_TILE': '31RDQ',
#    'PROCESSING_BASELINE': '02.02',
#    'PRODUCTION_DEM_TYPE': 'S2__OPER_DEM_GLOBEF_PDMC_19800101T000000_S19800101T000000',
#    'PRODUCT_ID': 'S2A_OPER_PRD_MSIL1C_PDMC_20160607T154824_R062_V20150627T102531_20150627T102531',
#    'PRODUCT_URI': '404_2016-06-07T01_10',
#    'RADIOMETRIC_QUALITY_FLAG': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.967962284766511,
#    'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#    'SENSING_ORBIT_NUMBER': 62.0,
#    'SENSOR_QUALITY_FLAG': 'PASSED',
#    'SOLAR_IRRADIANCE_B1': 1913.57,
#    'SOLAR_IRRADIANCE_B10': 367.15,
#    'SOLAR_IRRADIANCE_B11': 245.59,
#    'SOLAR_IRRADIANCE_B12': 85.25,
#    'SOLAR_IRRADIANCE_B2': 1941.63,
#    'SOLAR_IRRADIANCE_B3': 1822.61,
#    'SOLAR_IRRADIANCE_B4': 1512.79,
#    'SOLAR_IRRADIANCE_B5': 1425.56,
#    'SOLAR_IRRADIANCE_B6': 1288.32,
#    'SOLAR_IRRADIANCE_B7': 1163.19,
#    'SOLAR_IRRADIANCE_B8': 1036.39,
#    'SOLAR_IRRADIANCE_B8A': 955.19,
#    'SOLAR_IRRADIANCE_B9': 813.04,
#    'SPACECRAFT_NAME': 'Sentinel-2A',
#    'system:asset_size': 561044564,
#    'system:footprint': {'coordinates': [[2.4499443933158487,
#       30.643886349025387],
#      [2.4499766053756247, 30.64383785433704],
#      [2.4512574113712393, 30.64375101548992],
#      [3.101651034943776, 30.644869373441022],
#      [3.101755671298858, 30.644938870254382],
#      [3.1028189516707565, 31.635505688755686],
#      [3.10273733655819, 31.635595747657597],
#      [2.7071524526163997, 31.635301237622254],
#      [2.7070919945153213, 31.635286945938713],
#      [2.7067620934023595, 31.635003158173294],
#      [2.7067403225896824, 31.63497891722715],
#      [2.7061082148651265, 31.633066729365407],
#      [2.7054817288910398, 31.63089763014533],
#      [2.7026679171803725, 31.620334216301345],
#      [2.6992302231723126, 31.607333873721494],
#      [2.479650547701321, 30.760470421834903],
#      [2.45174196637429, 30.65153262369879],
#      [2.4499022989017223, 30.644206056226494],
#      [2.449903883099408, 30.643925526577085],
#      [2.4499443933158487, 30.643886349025387]],
#     'type': 'LinearRing'},
#    'system:index': '20150627T102531_20160606T223605_T31RDQ',
#    'system:time_end': 1435400731456,
#    'system:time_start': 1435400731456},
#   {'CLOUDY_PIXEL_PERCENTAGE': 0.0,
#    'CLOUD_COVERAGE_ASSESSMENT': 0.010707692307692307,
#    'DATASTRIP_ID': 'S2A_OPER_MSI_L1C_DS_EPA__20160606T223605_S20150627T102531_N02.02',
#    'DATATAKE_IDENTIFIER': 'GS2A_20150627T102537_000062_N02.02',
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0,
#    'ECMWF_DATA_REF': 'S2__OPER_AUX_ECMWFD_FAKE_19800101T000000_V19800101T000000_19800101T000000',
#    'FORMAT_CORRECTNESS_FLAG': 'PASSED',
#    'GENERAL_QUALITY_FLAG': 'PASSED',
#    'GENERATION_TIME': 1465314766000,
#    'GEOMETRIC_QUALITY_FLAG': 'PASSED',
#    'GRANULE_ID': 'S2A_OPER_MSI_L1C_TL_EPA__20160606T223605_A000062_T31REL_N02.02',
#    'GRI_FILENAME': 'S2A_OPER_AUX_GRI065_PDMC_20130621T120000_S20130101T000000',
#    'IERS_BULLETIN_FILENAME': 'S2__OPER_AUX_UT1UTC_PDMC_20150625T000000_V20150626T000000_20160625T000000',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 232.121151497716,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 234.162718655391,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 232.571388115359,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 231.545894099121,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 238.835940576043,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 236.19576473391,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 234.644681897186,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 233.772740878916,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 233.238314363224,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 232.885711282239,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 237.433594190817,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 232.50713368297,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 231.727775865739,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 3.94126464899164,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 3.55384217844187,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 3.70484904288365,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.88232996849354,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 3.37519889208503,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 3.46298082991822,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 3.5699211082947,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 3.63691791568873,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 3.70580681315284,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 3.78548357739445,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 3.41923708685031,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.86154198393829,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 4.01948646848839,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 100.113306146669,
#    'MEAN_SOLAR_ZENITH_ANGLE': 17.1181529731568,
#    'MGRS_TILE': '31REL',
#    'PROCESSING_BASELINE': '02.02',
#    'PRODUCTION_DEM_TYPE': 'S2__OPER_DEM_GLOBEF_PDMC_19800101T000000_S19800101T000000',
#    'PRODUCT_ID': 'S2A_OPER_PRD_MSIL1C_PDMC_20160607T155246_R062_V20150627T102531_20150627T102531',
#    'PRODUCT_URI': '754_2016-06-07T01_11',
#    'RADIOMETRIC_QUALITY_FLAG': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.967962284766511,
#    'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#    'SENSING_ORBIT_NUMBER': 62.0,
#    'SENSOR_QUALITY_FLAG': 'PASSED',
#    'SOLAR_IRRADIANCE_B1': 1913.57,
#    'SOLAR_IRRADIANCE_B10': 367.15,
#    'SOLAR_IRRADIANCE_B11': 245.59,
#    'SOLAR_IRRADIANCE_B12': 85.25,
#    'SOLAR_IRRADIANCE_B2': 1941.63,
#    'SOLAR_IRRADIANCE_B3': 1822.61,
#    'SOLAR_IRRADIANCE_B4': 1512.79,
#    'SOLAR_IRRADIANCE_B5': 1425.56,
#    'SOLAR_IRRADIANCE_B6': 1288.32,
#    'SOLAR_IRRADIANCE_B7': 1163.19,
#    'SOLAR_IRRADIANCE_B8': 1036.39,
#    'SOLAR_IRRADIANCE_B8A': 955.19,
#    'SOLAR_IRRADIANCE_B9': 813.04,
#    'SPACECRAFT_NAME': 'Sentinel-2A',
#    'system:asset_size': 806801441,
#    'system:footprint': {'coordinates': [[4.106532687944701, 27.23718499467123],
#      [4.10655726877196, 27.237182127232426],
#      [4.108576993917188, 27.237166090712865],
#      [4.108623972457866, 27.237202330081093],
#      [4.108675711331449, 27.23723305705304],
#      [4.108678988908879, 27.237247737607],
#      [4.112601460001989, 27.629088450441834],
#      [4.116603757816785, 28.02089897569779],
#      [4.116562781900188, 28.020940777094562],
#      [4.116528049957938, 28.02098676207516],
#      [4.116511347414152, 28.02098966855597],
#      [2.9997965289965287, 28.02552553328825],
#      [2.9997495880369094, 28.025488976913344],
#      [2.9996977622178, 28.025457882029006],
#      [2.999694632825509, 28.02544304433609],
#      [2.999696083031669, 27.488924381806715],
#      [2.9997289798252553, 27.488891271600522],
#      [2.9997424896518945, 27.48884882026569],
#      [2.9997653113450946, 27.488839021036544],
#      [3.004324448595456, 27.48748370424122],
#      [4.106532687944701, 27.23718499467123]],
#     'type': 'LinearRing'},
#    'system:index': '20150627T102531_20160606T223605_T31REL',
#    'system:time_end': 1435400731456,
#    'system:time_start': 1435400731456},
#   {'CLOUDY_PIXEL_PERCENTAGE': 0.0,
#    'CLOUD_COVERAGE_ASSESSMENT': 0.010707692307692307,
#    'DATASTRIP_ID': 'S2A_OPER_MSI_L1C_DS_EPA__20160606T223605_S20150627T102531_N02.02',
#    'DATATAKE_IDENTIFIER': 'GS2A_20150627T102537_000062_N02.02',
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0,
#    'ECMWF_DATA_REF': 'S2__OPER_AUX_ECMWFD_FAKE_19800101T000000_V19800101T000000_19800101T000000',
#    'FORMAT_CORRECTNESS_FLAG': 'PASSED',
#    'GENERAL_QUALITY_FLAG': 'PASSED',
#    'GENERATION_TIME': 1465314766000,
#    'GEOMETRIC_QUALITY_FLAG': 'PASSED',
#    'GRANULE_ID': 'S2A_OPER_MSI_L1C_TL_EPA__20160606T223605_A000062_T31REM_N02.02',
#    'GRI_FILENAME': 'S2A_OPER_AUX_GRI065_PDMC_20130621T120000_S20130101T000000',
#    'IERS_BULLETIN_FILENAME': 'S2__OPER_AUX_UT1UTC_PDMC_20150625T000000_V20150626T000000_20160625T000000',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 197.0445455568,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 198.027250159919,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 196.598797034019,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 195.869981522807,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 202.403491431346,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 200.17332629989,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 199.075399585268,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 198.509435624544,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 197.602274906133,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 197.243029859821,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 201.130494971098,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 197.298070839986,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 196.858846211331,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 3.19288625367828,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 2.75270129382842,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 2.92054673449654,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.1180102164866,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 2.56619189161802,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 2.67511952652928,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 2.79620625337125,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 2.86796029945854,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 2.93639463345294,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 3.01734532038575,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 2.61715585831042,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.10400397898364,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 3.28635501378439,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 102.908021226706,
#    'MEAN_SOLAR_ZENITH_ANGLE': 17.3471537151474,
#    'MGRS_TILE': '31REM',
#    'PROCESSING_BASELINE': '02.02',
#    'PRODUCTION_DEM_TYPE': 'S2__OPER_DEM_GLOBEF_PDMC_19800101T000000_S19800101T000000',
#    'PRODUCT_ID': 'S2A_OPER_PRD_MSIL1C_PDMC_20160607T155246_R062_V20150627T102531_20150627T102531',
#    'PRODUCT_URI': '754_2016-06-07T01_11',
#    'RADIOMETRIC_QUALITY_FLAG': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.967962284766511,
#    'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#    'SENSING_ORBIT_NUMBER': 62.0,
#    'SENSOR_QUALITY_FLAG': 'PASSED',
#    'SOLAR_IRRADIANCE_B1': 1913.57,
#    'SOLAR_IRRADIANCE_B10': 367.15,
#    'SOLAR_IRRADIANCE_B11': 245.59,
#    'SOLAR_IRRADIANCE_B12': 85.25,
#    'SOLAR_IRRADIANCE_B2': 1941.63,
#    'SOLAR_IRRADIANCE_B3': 1822.61,
#    'SOLAR_IRRADIANCE_B4': 1512.79,
#    'SOLAR_IRRADIANCE_B5': 1425.56,
#    'SOLAR_IRRADIANCE_B6': 1288.32,
#    'SOLAR_IRRADIANCE_B7': 1163.19,
#    'SOLAR_IRRADIANCE_B8': 1036.39,
#    'SOLAR_IRRADIANCE_B8A': 955.19,
#    'SOLAR_IRRADIANCE_B9': 813.04,
#    'SPACECRAFT_NAME': 'Sentinel-2A',
#    'system:asset_size': 1311301118,
#    'system:footprint': {'coordinates': [[2.9996928009862156,
#       28.928293952186962],
#      [2.999691961393227, 28.928282696890964],
#      [2.999694861805426, 27.93732887486436],
#      [2.999736230861679, 27.9372874354729],
#      [2.9997714174855843, 27.937241665169182],
#      [2.9997882093759434, 27.937238889853607],
#      [4.115594120586789, 27.93271983566745],
#      [4.115641417628316, 27.932756081059637],
#      [4.115693475642641, 27.932786741788398],
#      [4.115696831708316, 27.932801453549875],
#      [4.120850832084882, 28.428209581516402],
#      [4.126136799493734, 28.92357314721295],
#      [4.126095425788647, 28.92361494610814],
#      [4.126060453323831, 28.92366098445449],
#      [4.1260435916080755, 28.92366389423571],
#      [2.9997947734801396, 28.928372737816826],
#      [2.9997474508886226, 28.92833614879581],
#      [2.999695167111985, 28.92830508484487],
#      [2.9996928009862156, 28.928293952186962]],
#     'type': 'LinearRing'},
#    'system:index': '20150627T102531_20160606T223605_T31REM',
#    'system:time_end': 1435400731456,
#    'system:time_start': 1435400731456},
#   {'CLOUDY_PIXEL_PERCENTAGE': 0.0,
#    'CLOUD_COVERAGE_ASSESSMENT': 0.010707692307692307,
#    'DATASTRIP_ID': 'S2A_OPER_MSI_L1C_DS_EPA__20160606T223605_S20150627T102531_N02.02',
#    'DATATAKE_IDENTIFIER': 'GS2A_20150627T102537_000062_N02.02',
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0,
#    'ECMWF_DATA_REF': 'S2__OPER_AUX_ECMWFD_FAKE_19800101T000000_V19800101T000000_19800101T000000',
#    'FORMAT_CORRECTNESS_FLAG': 'PASSED',
#    'GENERAL_QUALITY_FLAG': 'PASSED',
#    'GENERATION_TIME': 1465314766000,
#    'GEOMETRIC_QUALITY_FLAG': 'PASSED',
#    'GRANULE_ID': 'S2A_OPER_MSI_L1C_TL_EPA__20160606T223605_A000062_T31REN_N02.02',
#    'GRI_FILENAME': 'S2A_OPER_AUX_GRI065_PDMC_20130621T120000_S20130101T000000',
#    'IERS_BULLETIN_FILENAME': 'S2__OPER_AUX_UT1UTC_PDMC_20150625T000000_V20150626T000000_20160625T000000',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 160.589077892386,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 161.338889057739,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 160.185865818826,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 159.569895117328,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 165.804275426932,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 163.416881290702,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 162.172635528497,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 161.670043046234,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 161.208022570335,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 160.910943257653,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 164.450665332691,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 160.756327491021,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 160.457198307963,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 3.13944143526119,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 2.69407878332553,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 2.87190796630865,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.0738188767249,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 2.49937132112013,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 2.60720713627284,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 2.72681441945445,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 2.80067958598814,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 2.88133718726175,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 2.96420089268478,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 2.54968409911396,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.04871209095967,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 3.23513142262077,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 105.619558524713,
#    'MEAN_SOLAR_ZENITH_ANGLE': 17.6171349796484,
#    'MGRS_TILE': '31REN',
#    'PROCESSING_BASELINE': '02.02',
#    'PRODUCTION_DEM_TYPE': 'S2__OPER_DEM_GLOBEF_PDMC_19800101T000000_S19800101T000000',
#    'PRODUCT_ID': 'S2A_OPER_PRD_MSIL1C_PDMC_20160607T155246_R062_V20150627T102531_20150627T102531',
#    'PRODUCT_URI': '754_2016-06-07T01_11',
#    'RADIOMETRIC_QUALITY_FLAG': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.967962284766511,
#    'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#    'SENSING_ORBIT_NUMBER': 62.0,
#    'SENSOR_QUALITY_FLAG': 'PASSED',
#    'SOLAR_IRRADIANCE_B1': 1913.57,
#    'SOLAR_IRRADIANCE_B10': 367.15,
#    'SOLAR_IRRADIANCE_B11': 245.59,
#    'SOLAR_IRRADIANCE_B12': 85.25,
#    'SOLAR_IRRADIANCE_B2': 1941.63,
#    'SOLAR_IRRADIANCE_B3': 1822.61,
#    'SOLAR_IRRADIANCE_B4': 1512.79,
#    'SOLAR_IRRADIANCE_B5': 1425.56,
#    'SOLAR_IRRADIANCE_B6': 1288.32,
#    'SOLAR_IRRADIANCE_B7': 1163.19,
#    'SOLAR_IRRADIANCE_B8': 1036.39,
#    'SOLAR_IRRADIANCE_B8A': 955.19,
#    'SOLAR_IRRADIANCE_B9': 813.04,
#    'SPACECRAFT_NAME': 'Sentinel-2A',
#    'system:asset_size': 1227073286,
#    'system:footprint': {'coordinates': [[2.999690053227401, 29.83047858013182],
#      [2.999689213634464, 29.83046730616292],
#      [2.9996922666997663, 28.839646201699047],
#      [2.9997340173872833, 28.83960468590588],
#      [2.9997695093166006, 28.83955904524893],
#      [2.9997863775330726, 28.839556184747696],
#      [4.12507756488532, 28.834864583723732],
#      [4.125125338878469, 28.834900757719915],
#      [4.12517787470889, 28.834931461634913],
#      [4.125181231383356, 28.83494618047638],
#      [4.130577559219396, 29.330286671880764],
#      [4.136110768476644, 29.8255819015793],
#      [4.1360690745716795, 29.825623753708392],
#      [4.136033783127512, 29.825669725626945],
#      [4.136016762041267, 29.825672725047706],
#      [2.999793017963814, 29.830557331607597],
#      [2.9997451610869956, 29.83052074125265],
#      [2.9996924956796724, 29.830489641401957],
#      [2.999690053227401, 29.83047858013182]],
#     'type': 'LinearRing'},
#    'system:index': '20150627T102531_20160606T223605_T31REN',
#    'system:time_end': 1435400731456,
#    'system:time_start': 1435400731456}],
#  'meta': {}}

# %%
# Other example
gridmet = register(
    payload = {
        # These are the required fields
        "name": "GRIDMET: University of Idaho Gridded Surface Meteorological Dataset", # The name will determine the slug
        "connectorType": "rest",
        "provider": "gee", # Google Earth Engine are of provider type 'gee'
        "application": ["data4sdgs"],
        "tableName": "IDAHO_EPSCOR/GRIDMET" # GEE image ID
})
gridmet
# Out:
# Doing authenticated request to the API
# Status code: 200
# {'data': {'attributes': {'application': ['data4sdgs'],
#    'attributesPath': None,
#    'blockchain': {},
#    'clonedHost': {},
#    'connectorType': 'rest',
#    'connectorUrl': None,
#    'dataPath': None,
#    'env': 'production',
#    'errorMessage': None,
#    'geoInfo': False,
#    'layerRelevantProps': [],
#    'legend': {'country': [], 'date': [], 'nested': [], 'region': []},
#    'mainDateField': None,
#    'name': 'GRIDMET: University of Idaho Gridded Surface Meteorological Dataset',
#    'overwrite': False,
#    'protected': False,
#    'provider': 'gee',
#    'published': True,
#    'slug': 'GRIDMET-University-of-Idaho-Gridded-Surface-Meteorological-Dataset_1',
#    'status': 'pending',
#    'subtitle': None,
#    'tableName': 'IDAHO_EPSCOR/GRIDMET',
#    'taskId': None,
#    'type': None,
#    'updatedAt': '2018-05-14T17:58:41.604Z',
#    'userId': '599c0e5458113b0001d75c47',
#    'verified': False,
#    'widgetRelevantProps': []},
#   'id': '53f86a5d-dc34-4cab-9738-0ccc88eec636',
#   'type': 'dataset'}}

# %%
query(
    gridmet["data"]["id"],
    "select * from 'IDAHO_EPSCOR/GRIDMET' limit 10"
)
# Out:
# {'data': [{'status': 'permanent',
#    'system:asset_size': 27576721,
#    'system:footprint': {'coordinates': [[-108.5453124696084,
#       49.46257585003468],
#      [-113.9593748919571, 49.46257584884527],
#      [-124.85170940475892, 49.4620585601637],
#      [-124.83351210930364, 24.93736504761038],
#      [-116.66640625473028, 24.963260502976674],
#      [-109.44765621625152, 24.96326051909946],
#      [-102.22890624654843, 24.963260484807783],
#      [-96.81484372072272, 24.995926577231895],
#      [-92.30312493334293, 24.982315870677233],
#      [-87.79140622110124, 24.995926539340573],
#      [-83.27968748970726, 24.98231580541047],
#      [-77.86562494351487, 24.982315792477387],
#      [-71.54921870653465, 24.96326053409072],
#      [-66.99145134929572, 25.003807969975153],
#      [-66.97329042095092, 49.4620585688528],
#      [-81.47499992614492, 49.4625758671273],
#      [-90.49843747394075, 49.462575896553865],
#      [-97.71718744154877, 49.462575845088494],
#      [-108.5453124696084, 49.46257585003468]],
#     'type': 'LinearRing'},
#    'system:index': '19790101',
#    'system:time_start': 284018400000},
#   {'status': 'permanent',
#    'system:asset_size': 27594110,
#    'system:footprint': {'coordinates': [[-108.5453124696084,
#       49.46257585003468],
#      [-113.9593748919571, 49.46257584884527],
#      [-124.85170940475892, 49.4620585601637],
#      [-124.83351210930364, 24.93736504761038],
#      [-116.66640625473028, 24.963260502976674],
#      [-109.44765621625152, 24.96326051909946],
#      [-102.22890624654843, 24.963260484807783],
#      [-96.81484372072272, 24.995926577231895],
#      [-92.30312493334293, 24.982315870677233],
#      [-87.79140622110124, 24.995926539340573],
#      [-83.27968748970726, 24.98231580541047],
#      [-77.86562494351487, 24.982315792477387],
#      [-71.54921870653465, 24.96326053409072],
#      [-66.99145134929572, 25.003807969975153],
#      [-66.97329042095092, 49.4620585688528],
#      [-81.47499992614492, 49.4625758671273],
#      [-90.49843747394075, 49.462575896553865],
#      [-97.71718744154877, 49.462575845088494],
#      [-108.5453124696084, 49.46257585003468]],
#     'type': 'LinearRing'},
#    'system:index': '19790102',
#    'system:time_start': 284104800000},
#   {'status': 'permanent',
#    'system:asset_size': 27765055,
#    'system:footprint': {'coordinates': [[-108.5453124696084,
#       49.46257585003468],
#      [-113.9593748919571, 49.46257584884527],
#      [-124.85170940475892, 49.4620585601637],
#      [-124.83351210930364, 24.93736504761038],
#      [-116.66640625473028, 24.963260502976674],
#      [-109.44765621625152, 24.96326051909946],
#      [-102.22890624654843, 24.963260484807783],
#      [-96.81484372072272, 24.995926577231895],
#      [-92.30312493334293, 24.982315870677233],
#      [-87.79140622110124, 24.995926539340573],
#      [-83.27968748970726, 24.98231580541047],
#      [-77.86562494351487, 24.982315792477387],
#      [-71.54921870653465, 24.96326053409072],
#      [-66.99145134929572, 25.003807969975153],
#      [-66.97329042095092, 49.4620585688528],
#      [-81.47499992614492, 49.4625758671273],
#      [-90.49843747394075, 49.462575896553865],
#      [-97.71718744154877, 49.462575845088494],
#      [-108.5453124696084, 49.46257585003468]],
#     'type': 'LinearRing'},
#    'system:index': '19790103',
#    'system:time_start': 284191200000},
#   {'status': 'permanent',
#    'system:asset_size': 27988164,
#    'system:footprint': {'coordinates': [[-108.5453124696084,
#       49.46257585003468],
#      [-113.9593748919571, 49.46257584884527],
#      [-124.85170940475892, 49.4620585601637],
#      [-124.83351210930364, 24.93736504761038],
#      [-116.66640625473028, 24.963260502976674],
#      [-109.44765621625152, 24.96326051909946],
#      [-102.22890624654843, 24.963260484807783],
#      [-96.81484372072272, 24.995926577231895],
#      [-92.30312493334293, 24.982315870677233],
#      [-87.79140622110124, 24.995926539340573],
#      [-83.27968748970726, 24.98231580541047],
#      [-77.86562494351487, 24.982315792477387],
#      [-71.54921870653465, 24.96326053409072],
#      [-66.99145134929572, 25.003807969975153],
#      [-66.97329042095092, 49.4620585688528],
#      [-81.47499992614492, 49.4625758671273],
#      [-90.49843747394075, 49.462575896553865],
#      [-97.71718744154877, 49.462575845088494],
#      [-108.5453124696084, 49.46257585003468]],
#     'type': 'LinearRing'},
#    'system:index': '19790104',
#    'system:time_start': 284277600000},
#   {'status': 'permanent',
#    'system:asset_size': 27870540,
#    'system:footprint': {'coordinates': [[-108.5453124696084,
#       49.46257585003468],
#      [-113.9593748919571, 49.46257584884527],
#      [-124.85170940475892, 49.4620585601637],
#      [-124.83351210930364, 24.93736504761038],
#      [-116.66640625473028, 24.963260502976674],
#      [-109.44765621625152, 24.96326051909946],
#      [-102.22890624654843, 24.963260484807783],
#      [-96.81484372072272, 24.995926577231895],
#      [-92.30312493334293, 24.982315870677233],
#      [-87.79140622110124, 24.995926539340573],
#      [-83.27968748970726, 24.98231580541047],
#      [-77.86562494351487, 24.982315792477387],
#      [-71.54921870653465, 24.96326053409072],
#      [-66.99145134929572, 25.003807969975153],
#      [-66.97329042095092, 49.4620585688528],
#      [-81.47499992614492, 49.4625758671273],
#      [-90.49843747394075, 49.462575896553865],
#      [-97.71718744154877, 49.462575845088494],
#      [-108.5453124696084, 49.46257585003468]],
#     'type': 'LinearRing'},
#    'system:index': '19790105',
#    'system:time_start': 284364000000},
#   {'status': 'permanent',
#    'system:asset_size': 27935163,
#    'system:footprint': {'coordinates': [[-108.5453124696084,
#       49.46257585003468],
#      [-113.9593748919571, 49.46257584884527],
#      [-124.85170940475892, 49.4620585601637],
#      [-124.83351210930364, 24.93736504761038],
#      [-116.66640625473028, 24.963260502976674],
#      [-109.44765621625152, 24.96326051909946],
#      [-102.22890624654843, 24.963260484807783],
#      [-96.81484372072272, 24.995926577231895],
#      [-92.30312493334293, 24.982315870677233],
#      [-87.79140622110124, 24.995926539340573],
#      [-83.27968748970726, 24.98231580541047],
#      [-77.86562494351487, 24.982315792477387],
#      [-71.54921870653465, 24.96326053409072],
#      [-66.99145134929572, 25.003807969975153],
#      [-66.97329042095092, 49.4620585688528],
#      [-81.47499992614492, 49.4625758671273],
#      [-90.49843747394075, 49.462575896553865],
#      [-97.71718744154877, 49.462575845088494],
#      [-108.5453124696084, 49.46257585003468]],
#     'type': 'LinearRing'},
#    'system:index': '19790106',
#    'system:time_start': 284450400000},
#   {'status': 'permanent',
#    'system:asset_size': 27889042,
#    'system:footprint': {'coordinates': [[-108.5453124696084,
#       49.46257585003468],
#      [-113.9593748919571, 49.46257584884527],
#      [-124.85170940475892, 49.4620585601637],
#      [-124.83351210930364, 24.93736504761038],
#      [-116.66640625473028, 24.963260502976674],
#      [-109.44765621625152, 24.96326051909946],
#      [-102.22890624654843, 24.963260484807783],
#      [-96.81484372072272, 24.995926577231895],
#      [-92.30312493334293, 24.982315870677233],
#      [-87.79140622110124, 24.995926539340573],
#      [-83.27968748970726, 24.98231580541047],
#      [-77.86562494351487, 24.982315792477387],
#      [-71.54921870653465, 24.96326053409072],
#      [-66.99145134929572, 25.003807969975153],
#      [-66.97329042095092, 49.4620585688528],
#      [-81.47499992614492, 49.4625758671273],
#      [-90.49843747394075, 49.462575896553865],
#      [-97.71718744154877, 49.462575845088494],
#      [-108.5453124696084, 49.46257585003468]],
#     'type': 'LinearRing'},
#    'system:index': '19790107',
#    'system:time_start': 284536800000},
#   {'status': 'permanent',
#    'system:asset_size': 27997006,
#    'system:footprint': {'coordinates': [[-108.5453124696084,
#       49.46257585003468],
#      [-113.9593748919571, 49.46257584884527],
#      [-124.85170940475892, 49.4620585601637],
#      [-124.83351210930364, 24.93736504761038],
#      [-116.66640625473028, 24.963260502976674],
#      [-109.44765621625152, 24.96326051909946],
#      [-102.22890624654843, 24.963260484807783],
#      [-96.81484372072272, 24.995926577231895],
#      [-92.30312493334293, 24.982315870677233],
#      [-87.79140622110124, 24.995926539340573],
#      [-83.27968748970726, 24.98231580541047],
#      [-77.86562494351487, 24.982315792477387],
#      [-71.54921870653465, 24.96326053409072],
#      [-66.99145134929572, 25.003807969975153],
#      [-66.97329042095092, 49.4620585688528],
#      [-81.47499992614492, 49.4625758671273],
#      [-90.49843747394075, 49.462575896553865],
#      [-97.71718744154877, 49.462575845088494],
#      [-108.5453124696084, 49.46257585003468]],
#     'type': 'LinearRing'},
#    'system:index': '19790108',
#    'system:time_start': 284623200000},
#   {'status': 'permanent',
#    'system:asset_size': 27981423,
#    'system:footprint': {'coordinates': [[-108.5453124696084,
#       49.46257585003468],
#      [-113.9593748919571, 49.46257584884527],
#      [-124.85170940475892, 49.4620585601637],
#      [-124.83351210930364, 24.93736504761038],
#      [-116.66640625473028, 24.963260502976674],
#      [-109.44765621625152, 24.96326051909946],
#      [-102.22890624654843, 24.963260484807783],
#      [-96.81484372072272, 24.995926577231895],
#      [-92.30312493334293, 24.982315870677233],
#      [-87.79140622110124, 24.995926539340573],
#      [-83.27968748970726, 24.98231580541047],
#      [-77.86562494351487, 24.982315792477387],
#      [-71.54921870653465, 24.96326053409072],
#      [-66.99145134929572, 25.003807969975153],
#      [-66.97329042095092, 49.4620585688528],
#      [-81.47499992614492, 49.4625758671273],
#      [-90.49843747394075, 49.462575896553865],
#      [-97.71718744154877, 49.462575845088494],
#      [-108.5453124696084, 49.46257585003468]],
#     'type': 'LinearRing'},
#    'system:index': '19790109',
#    'system:time_start': 284709600000},
#   {'status': 'permanent',
#    'system:asset_size': 27945672,
#    'system:footprint': {'coordinates': [[-108.5453124696084,
#       49.46257585003468],
#      [-113.9593748919571, 49.46257584884527],
#      [-124.85170940475892, 49.4620585601637],
#      [-124.83351210930364, 24.93736504761038],
#      [-116.66640625473028, 24.963260502976674],
#      [-109.44765621625152, 24.96326051909946],
#      [-102.22890624654843, 24.963260484807783],
#      [-96.81484372072272, 24.995926577231895],
#      [-92.30312493334293, 24.982315870677233],
#      [-87.79140622110124, 24.995926539340573],
#      [-83.27968748970726, 24.98231580541047],
#      [-77.86562494351487, 24.982315792477387],
#      [-71.54921870653465, 24.96326053409072],
#      [-66.99145134929572, 25.003807969975153],
#      [-66.97329042095092, 49.4620585688528],
#      [-81.47499992614492, 49.4625758671273],
#      [-90.49843747394075, 49.462575896553865],
#      [-97.71718744154877, 49.462575845088494],
#      [-108.5453124696084, 49.46257585003468]],
#     'type': 'LinearRing'},
#    'system:index': '19790110',
#    'system:time_start': 284796000000}],
#  'meta': {}}

# %% [markdown]
# [FeatureCollections](https://developers.google.com/earth-engine/feature_collections) are the homolog of vector layers in the Google Earth Engine ecosystem.

# %%
glims_2016 = register(
    payload = {
        # These are the required fields
        "name": "Global Land Ice Measurements 2016", # The name will determine the slug
        "connectorType": "rest",
        "provider": "gee", # Google Earth Engine are of provider type 'gee'
        "application": ["data4sdgs"],
        "tableName": "GLIMS/2016" # GEE image ID
})

sea_temp_salinity = register(
    payload = {
        # These are the required fields
        "name": "HYCOM + NCODA Global 1/12° Analysis", # The name will determine the slug
        "connectorType": "rest",
        "provider": "gee", # Google Earth Engine are of provider type 'gee'
        "application": ["data4sdgs"],
        "tableName": "HYCOM/GLBu0_08/sea_temp_salinity" # GEE image ID
})

(glims_2016, sea_temp_salinity)
# Out:
# Doing authenticated request to the API
# Status code: 200
# Doing authenticated request to the API
# Status code: 200
# ({'data': {'attributes': {'application': ['data4sdgs'],
#     'attributesPath': None,
#     'blockchain': {},
#     'clonedHost': {},
#     'connectorType': 'rest',
#     'connectorUrl': None,
#     'dataPath': None,
#     'env': 'production',
#     'errorMessage': None,
#     'geoInfo': False,
#     'layerRelevantProps': [],
#     'legend': {'country': [], 'date': [], 'nested': [], 'region': []},
#     'mainDateField': None,
#     'name': 'Global Land Ice Measurements 2016',
#     'overwrite': False,
#     'protected': False,
#     'provider': 'gee',
#     'published': True,
#     'slug': 'Global-Land-Ice-Measurements-2016',
#     'status': 'pending',
#     'subtitle': None,
#     'tableName': 'GLIMS/2016',
#     'taskId': None,
#     'type': None,
#     'updatedAt': '2018-05-14T18:05:29.282Z',
#     'userId': '599c0e5458113b0001d75c47',
#     'verified': False,
#     'widgetRelevantProps': []},
#    'id': '7416e29b-908a-4e06-a9b0-8bebb1e435b7',
#    'type': 'dataset'}},
#  {'data': {'attributes': {'application': ['data4sdgs'],
#     'attributesPath': None,
#     'blockchain': {},
#     'clonedHost': {},
#     'connectorType': 'rest',
#     'connectorUrl': None,
#     'dataPath': None,
#     'env': 'production',
#     'errorMessage': None,
#     'geoInfo': False,
#     'layerRelevantProps': [],
#     'legend': {'country': [], 'date': [], 'nested': [], 'region': []},
#     'mainDateField': None,
#     'name': 'HYCOM + NCODA Global 1/12° Analysis',
#     'overwrite': False,
#     'protected': False,
#     'provider': 'gee',
#     'published': True,
#     'slug': 'HYCOM-NCODA-Global-112degree-Analysis',
#     'status': 'pending',
#     'subtitle': None,
#     'tableName': 'HYCOM/GLBu0_08/sea_temp_salinity',
#     'taskId': None,
#     'type': None,
#     'updatedAt': '2018-05-14T18:05:29.459Z',
#     'userId': '599c0e5458113b0001d75c47',
#     'verified': False,
#     'widgetRelevantProps': []},
#    'id': '43d899d4-9329-4b6e-bd3d-6cbf0107c931',
#    'type': 'dataset'}})

# %%
query(
    glims_2016["data"]["id"],
    "SELECT * from 'GLIMS/2016' where area > 0.09 limit 10"
)
# Out:
# {'data': [{'analysts': 'Rabatel, Antoine',
#    'anlys_id': 121404,
#    'anlys_time': '2013-03-20T00:00:00',
#    'area': 0.0905,
#    'chief_affl': "Laboratoire de Glaciologie et G�ophysique de l'Environnement (LGGE)",
#    'db_area': 0.090459,
#    'geog_area': 'French Alps',
#    'glac_id': 'G006237E44775N',
#    'glac_name': 'Plat',
#    'glac_stat': 'exists',
#    'length': 506.485,
#    'line_type': 'glac_bound',
#    'local_id': 'None',
#    'max_elev': 2970,
#    'mean_elev': 2892,
#    'min_elev': 2802,
#    'parent_id': '',
#    'primeclass': 0,
#    'proc_desc': 'Automatic delineation using combination of SWIR, NIR, and GREEN; individual checking and manual corrections when necessary; First, NDSI was calculated on the images.  From the resulting maps, glacier outlines were extracted.  Second, the shapefiles result',
#    'rc_id': 33,
#    'rec_status': 'okay',
#    'release_dt': '2013-12-25T14:01:59',
#    'src_date': '1988-09-12T00:00:00',
#    'subm_id': 569,
#    'submitters': 'Rabatel, Antoine',
#    'system:index': '0000f1dd8747bff0d0b9',
#    'wgms_id': 'F4N01172H02',
#    'width': 0.0},
#   {'analysts': 'Rabatel, Antoine',
#    'anlys_id': 121403,
#    'anlys_time': '2013-03-20T00:00:00',
#    'area': 0.127855,
#    'chief_affl': "Laboratoire de Glaciologie et G�ophysique de l'Environnement (LGGE)",
#    'db_area': 0.127806,
#    'geog_area': 'French Alps',
#    'glac_id': 'G006231E44772N',
#    'glac_name': 'de Crupillouse',
#    'glac_stat': 'exists',
#    'length': 409.454,
#    'line_type': 'glac_bound',
#    'local_id': 'None',
#    'max_elev': 2961,
#    'mean_elev': 2768,
#    'min_elev': 2598,
#    'parent_id': '',
#    'primeclass': 0,
#    'proc_desc': 'Automatic delineation using combination of SWIR, NIR, and GREEN; individual checking and manual corrections when necessary; First, NDSI was calculated on the images.  From the resulting maps, glacier outlines were extracted.  Second, the shapefiles result',
#    'rc_id': 33,
#    'rec_status': 'okay',
#    'release_dt': '2013-12-25T14:01:59',
#    'src_date': '1988-09-12T00:00:00',
#    'subm_id': 569,
#    'submitters': 'Rabatel, Antoine',
#    'system:index': '00001dfaf3b44f3037c0',
#    'wgms_id': 'F4N01172H03',
#    'width': 0.0},
#   {'analysts': 'Rabatel, Antoine',
#    'anlys_id': 120866,
#    'anlys_time': '2013-03-25T00:00:00',
#    'area': 0.1112,
#    'chief_affl': "Laboratoire de Glaciologie et G�ophysique de l'Environnement (LGGE)",
#    'db_area': 0.111206,
#    'geog_area': 'French Alps',
#    'glac_id': 'G006231E44772N',
#    'glac_name': 'de Crupillouse',
#    'glac_stat': 'exists',
#    'length': 325.129,
#    'line_type': 'glac_bound',
#    'local_id': 'None',
#    'max_elev': 2961,
#    'mean_elev': 2784,
#    'min_elev': 2628,
#    'parent_id': '',
#    'primeclass': 0,
#    'proc_desc': 'Manual adjustment of the 1985 contour lines for each individual glacier; This submission concerns the glacier outlines in 2003. The shapefiles resulting from the 1985 delineation have been overlaid on the 2003 images displayed with a band combination asso',
#    'rc_id': 33,
#    'rec_status': 'okay',
#    'release_dt': '2013-12-25T14:08:34',
#    'src_date': '2003-09-21T00:00:00',
#    'subm_id': 568,
#    'submitters': 'Rabatel, Antoine',
#    'system:index': '0000f9b488ead489eced',
#    'wgms_id': 'F4N01172H03',
#    'width': 0.0},
#   {'analysts': 'Rabatel, Antoine',
#    'anlys_id': 120866,
#    'anlys_time': '2013-03-25T00:00:00',
#    'area': 0.1112,
#    'chief_affl': "Laboratoire de Glaciologie et G�ophysique de l'Environnement (LGGE)",
#    'db_area': 0.111206,
#    'geog_area': 'French Alps',
#    'glac_id': 'G006231E44772N',
#    'glac_name': 'de Crupillouse',
#    'glac_stat': 'exists',
#    'length': 325.129,
#    'line_type': 'debris_cov',
#    'local_id': 'None',
#    'max_elev': 2961,
#    'mean_elev': 2784,
#    'min_elev': 2628,
#    'parent_id': '',
#    'primeclass': 0,
#    'proc_desc': 'Manual adjustment of the 1985 contour lines for each individual glacier; This submission concerns the glacier outlines in 2003. The shapefiles resulting from the 1985 delineation have been overlaid on the 2003 images displayed with a band combination asso',
#    'rc_id': 33,
#    'rec_status': 'okay',
#    'release_dt': '2013-12-25T14:08:34',
#    'src_date': '2003-09-21T00:00:00',
#    'subm_id': 568,
#    'submitters': 'Rabatel, Antoine',
#    'system:index': '00001debd5b09c25aa80',
#    'wgms_id': 'F4N01172H03',
#    'width': 0.0},
#   {'analysts': 'Rabatel, Antoine',
#    'anlys_id': 120864,
#    'anlys_time': '2013-03-25T00:00:00',
#    'area': 0.2743,
#    'chief_affl': "Laboratoire de Glaciologie et G�ophysique de l'Environnement (LGGE)",
#    'db_area': 0.308945,
#    'geog_area': 'French Alps',
#    'glac_id': 'G006197E44744N',
#    'glac_name': "de l'Aup",
#    'glac_stat': 'exists',
#    'length': 795.945,
#    'line_type': 'glac_bound',
#    'local_id': 'None',
#    'max_elev': 3042,
#    'mean_elev': 2793,
#    'min_elev': 2510,
#    'parent_id': '',
#    'primeclass': 0,
#    'proc_desc': 'Manual adjustment of the 1985 contour lines for each individual glacier; This submission concerns the glacier outlines in 2003. The shapefiles resulting from the 1985 delineation have been overlaid on the 2003 images displayed with a band combination asso',
#    'rc_id': 33,
#    'rec_status': 'okay',
#    'release_dt': '2013-12-25T14:08:34',
#    'src_date': '2003-09-21T00:00:00',
#    'subm_id': 568,
#    'submitters': 'Rabatel, Antoine',
#    'system:index': '000050908e04cfe70938',
#    'wgms_id': 'F4N01172H04',
#    'width': 0.0},
#   {'analysts': 'Rabatel, Antoine',
#    'anlys_id': 121401,
#    'anlys_time': '2013-03-20T00:00:00',
#    'area': 0.505062,
#    'chief_affl': "Laboratoire de Glaciologie et G�ophysique de l'Environnement (LGGE)",
#    'db_area': 0.504848,
#    'geog_area': 'French Alps',
#    'glac_id': 'G006197E44744N',
#    'glac_name': "de l'Aup",
#    'glac_stat': 'exists',
#    'length': 1129.22,
#    'line_type': 'glac_bound',
#    'local_id': 'None',
#    'max_elev': 3042,
#    'mean_elev': 2734,
#    'min_elev': 2368,
#    'parent_id': '',
#    'primeclass': 0,
#    'proc_desc': 'Automatic delineation using combination of SWIR, NIR, and GREEN; individual checking and manual corrections when necessary; First, NDSI was calculated on the images.  From the resulting maps, glacier outlines were extracted.  Second, the shapefiles result',
#    'rc_id': 33,
#    'rec_status': 'okay',
#    'release_dt': '2013-12-25T14:01:59',
#    'src_date': '1988-09-12T00:00:00',
#    'subm_id': 569,
#    'submitters': 'Rabatel, Antoine',
#    'system:index': '0000b2eae8e599443cd0',
#    'wgms_id': 'F4N01172H04',
#    'width': 0.0},
#   {'analysts': 'Rabatel, Antoine',
#    'anlys_id': 120864,
#    'anlys_time': '2013-03-25T00:00:00',
#    'area': 0.2743,
#    'chief_affl': "Laboratoire de Glaciologie et G�ophysique de l'Environnement (LGGE)",
#    'db_area': 0.308945,
#    'geog_area': 'French Alps',
#    'glac_id': 'G006197E44744N',
#    'glac_name': "de l'Aup",
#    'glac_stat': 'exists',
#    'length': 795.945,
#    'line_type': 'glac_bound',
#    'local_id': 'None',
#    'max_elev': 3042,
#    'mean_elev': 2793,
#    'min_elev': 2510,
#    'parent_id': '',
#    'primeclass': 0,
#    'proc_desc': 'Manual adjustment of the 1985 contour lines for each individual glacier; This submission concerns the glacier outlines in 2003. The shapefiles resulting from the 1985 delineation have been overlaid on the 2003 images displayed with a band combination asso',
#    'rc_id': 33,
#    'rec_status': 'okay',
#    'release_dt': '2013-12-25T14:08:34',
#    'src_date': '2003-09-21T00:00:00',
#    'subm_id': 568,
#    'submitters': 'Rabatel, Antoine',
#    'system:index': '000064763710a43c67b5',
#    'wgms_id': 'F4N01172H04',
#    'width': 0.0},
#   {'analysts': 'Rabatel, Antoine',
#    'anlys_id': 121402,
#    'anlys_time': '2013-03-20T00:00:00',
#    'area': 0.206396,
#    'chief_affl': "Laboratoire de Glaciologie et G�ophysique de l'Environnement (LGGE)",
#    'db_area': 0.206302,
#    'geog_area': 'French Alps',
#    'glac_id': 'G006210E44747N',
#    'glac_name': 'du Mourre la Mine',
#    'glac_stat': 'exists',
#    'length': 787.47,
#    'line_type': 'glac_bound',
#    'local_id': 'None',
#    'max_elev': 3003,
#    'mean_elev': 2831,
#    'min_elev': 2614,
#    'parent_id': '',
#    'primeclass': 0,
#    'proc_desc': 'Automatic delineation using combination of SWIR, NIR, and GREEN; individual checking and manual corrections when necessary; First, NDSI was calculated on the images.  From the resulting maps, glacier outlines were extracted.  Second, the shapefiles result',
#    'rc_id': 33,
#    'rec_status': 'okay',
#    'release_dt': '2013-12-25T14:01:59',
#    'src_date': '1988-09-12T00:00:00',
#    'subm_id': 569,
#    'submitters': 'Rabatel, Antoine',
#    'system:index': '0000b1114721cc77d606',
#    'wgms_id': 'F4N01173B01',
#    'width': 0.0},
#   {'analysts': 'Rabatel, Antoine',
#    'anlys_id': 120865,
#    'anlys_time': '2013-03-25T00:00:00',
#    'area': 0.1845,
#    'chief_affl': "Laboratoire de Glaciologie et G�ophysique de l'Environnement (LGGE)",
#    'db_area': 0.181097,
#    'geog_area': 'French Alps',
#    'glac_id': 'G006210E44747N',
#    'glac_name': 'du Mourre la Mine',
#    'glac_stat': 'exists',
#    'length': 787.47,
#    'line_type': 'debris_cov',
#    'local_id': 'None',
#    'max_elev': 3003,
#    'mean_elev': 2831,
#    'min_elev': 2614,
#    'parent_id': '',
#    'primeclass': 0,
#    'proc_desc': 'Manual adjustment of the 1985 contour lines for each individual glacier; This submission concerns the glacier outlines in 2003. The shapefiles resulting from the 1985 delineation have been overlaid on the 2003 images displayed with a band combination asso',
#    'rc_id': 33,
#    'rec_status': 'okay',
#    'release_dt': '2013-12-25T14:08:34',
#    'src_date': '2003-09-21T00:00:00',
#    'subm_id': 568,
#    'submitters': 'Rabatel, Antoine',
#    'system:index': '00005c747d4f72be8159',
#    'wgms_id': 'F4N01173B01',
#    'width': 0.0},
#   {'analysts': 'Rabatel, Antoine',
#    'anlys_id': 120865,
#    'anlys_time': '2013-03-25T00:00:00',
#    'area': 0.1845,
#    'chief_affl': "Laboratoire de Glaciologie et G�ophysique de l'Environnement (LGGE)",
#    'db_area': 0.181097,
#    'geog_area': 'French Alps',
#    'glac_id': 'G006210E44747N',
#    'glac_name': 'du Mourre la Mine',
#    'glac_stat': 'exists',
#    'length': 787.47,
#    'line_type': 'glac_bound',
#    'local_id': 'None',
#    'max_elev': 3003,
#    'mean_elev': 2831,
#    'min_elev': 2614,
#    'parent_id': '',
#    'primeclass': 0,
#    'proc_desc': 'Manual adjustment of the 1985 contour lines for each individual glacier; This submission concerns the glacier outlines in 2003. The shapefiles resulting from the 1985 delineation have been overlaid on the 2003 images displayed with a band combination asso',
#    'rc_id': 33,
#    'rec_status': 'okay',
#    'release_dt': '2013-12-25T14:08:34',
#    'src_date': '2003-09-21T00:00:00',
#    'subm_id': 568,
#    'submitters': 'Rabatel, Antoine',
#    'system:index': '00000b15d40029b45406',
#    'wgms_id': 'F4N01173B01',
#    'width': 0.0}],
#  'meta': {}}

# %%
query(
    sea_temp_salinity["data"]["id"],
    "SELECT * from 'HYCOM/GLBu0_08/sea_temp_salinity' limit 10"
)
# Out:
# {'data': [{'experiment': '190',
#    'system:asset_size': 743581341,
#    'system:footprint': {'coordinates': [[-180.0, -90.0],
#      [180.0, -90.0],
#      [180.0, 90.0],
#      [-180.0, 90.0],
#      [-180.0, -90.0]],
#     'type': 'LinearRing'},
#    'system:index': '1992100200',
#    'system:time_end': 717984000000.0,
#    'system:time_start': 717984000000.0},
#   {'experiment': '190',
#    'system:asset_size': 744232323,
#    'system:footprint': {'coordinates': [[-180.0, -90.0],
#      [180.0, -90.0],
#      [180.0, 90.0],
#      [-180.0, 90.0],
#      [-180.0, -90.0]],
#     'type': 'LinearRing'},
#    'system:index': '1992100300',
#    'system:time_end': 718070400000.0,
#    'system:time_start': 718070400000.0},
#   {'experiment': '190',
#    'system:asset_size': 745010814,
#    'system:footprint': {'coordinates': [[-180.0, -90.0],
#      [180.0, -90.0],
#      [180.0, 90.0],
#      [-180.0, 90.0],
#      [-180.0, -90.0]],
#     'type': 'LinearRing'},
#    'system:index': '1992100400',
#    'system:time_end': 718156800000.0,
#    'system:time_start': 718156800000.0},
#   {'experiment': '190',
#    'system:asset_size': 745431269,
#    'system:footprint': {'coordinates': [[-180.0, -90.0],
#      [180.0, -90.0],
#      [180.0, 90.0],
#      [-180.0, 90.0],
#      [-180.0, -90.0]],
#     'type': 'LinearRing'},
#    'system:index': '1992100500',
#    'system:time_end': 718243200000.0,
#    'system:time_start': 718243200000.0},
#   {'experiment': '190',
#    'system:asset_size': 752259320,
#    'system:footprint': {'coordinates': [[-180.0, -90.0],
#      [180.0, -90.0],
#      [180.0, 90.0],
#      [-180.0, 90.0],
#      [-180.0, -90.0]],
#     'type': 'LinearRing'},
#    'system:index': '1992100600',
#    'system:time_end': 718329600000.0,
#    'system:time_start': 718329600000.0},
#   {'experiment': '190',
#    'system:asset_size': 755183636,
#    'system:footprint': {'coordinates': [[-180.0, -90.0],
#      [180.0, -90.0],
#      [180.0, 90.0],
#      [-180.0, 90.0],
#      [-180.0, -90.0]],
#     'type': 'LinearRing'},
#    'system:index': '1992100700',
#    'system:time_end': 718416000000.0,
#    'system:time_start': 718416000000.0},
#   {'experiment': '190',
#    'system:asset_size': 757945399,
#    'system:footprint': {'coordinates': [[-180.0, -90.0],
#      [180.0, -90.0],
#      [180.0, 90.0],
#      [-180.0, 90.0],
#      [-180.0, -90.0]],
#     'type': 'LinearRing'},
#    'system:index': '1992100800',
#    'system:time_end': 718502400000.0,
#    'system:time_start': 718502400000.0},
#   {'experiment': '190',
#    'system:asset_size': 759932427,
#    'system:footprint': {'coordinates': [[-180.0, -90.0],
#      [180.0, -90.0],
#      [180.0, 90.0],
#      [-180.0, 90.0],
#      [-180.0, -90.0]],
#     'type': 'LinearRing'},
#    'system:index': '1992100900',
#    'system:time_end': 718588800000.0,
#    'system:time_start': 718588800000.0},
#   {'experiment': '190',
#    'system:asset_size': 762016769,
#    'system:footprint': {'coordinates': [[-180.0, -90.0],
#      [180.0, -90.0],
#      [180.0, 90.0],
#      [-180.0, 90.0],
#      [-180.0, -90.0]],
#     'type': 'LinearRing'},
#    'system:index': '1992101000',
#    'system:time_end': 718675200000.0,
#    'system:time_start': 718675200000.0},
#   {'experiment': '190',
#    'system:asset_size': 763582993,
#    'system:footprint': {'coordinates': [[-180.0, -90.0],
#      [180.0, -90.0],
#      [180.0, 90.0],
#      [-180.0, 90.0],
#      [-180.0, -90.0]],
#     'type': 'LinearRing'},
#    'system:index': '1992101100',
#    'system:time_end': 718761600000.0,
#    'system:time_start': 718761600000.0}],
#  'meta': {}}
